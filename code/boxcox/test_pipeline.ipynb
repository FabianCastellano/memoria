# %%
from box_cox_img import BoxCoxImg
import matplotlib.pyplot as plt

img_path = './img/1.png'
BCI = BoxCoxImg(img_path)

full_bc, lam_full = BCI.transform()
plt.imshow(full_bc, cmap='gray')

# %%
hist_bc, lam_hist = BCI.transform(Method = 'hist')
plt.imshow(hist_bc, cmap='gray')

# %%
hist_bc = BCI.transform(Method = 'grid')
plt.imshow(hist_bc, cmap='gray')
# Out:
# (512, 768)
# /home/fcastellano/.conda/envs/memoria/lib/python3.10/site-packages/numpy/core/_methods.py:176: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)

# %%
hist_bc = BCI.transform(Method = 'moving_window')
plt.imshow(hist_bc, cmap='gray')
# Out:
# /home/fcastellano/.conda/envs/memoria/lib/python3.10/site-packages/scipy/stats/_morestats.py:933: RuntimeWarning: overflow encountered in power
#   variance = np.var(data**lmb / lmb, axis=0)
# /home/fcastellano/.conda/envs/memoria/lib/python3.10/site-packages/numpy/core/_methods.py:173: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# /home/fcastellano/.conda/envs/memoria/lib/python3.10/site-packages/numpy/core/_methods.py:187: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# /home/fcastellano/.conda/envs/memoria/lib/python3.10/site-packages/scipy/stats/_morestats.py:935: RuntimeWarning: divide by zero encountered in log
#   return (lmb - 1) * np.sum(logdata, axis=0) - N/2 * np.log(variance)
# /home/fcastellano/.conda/envs/memoria/lib/python3.10/site-packages/scipy/optimize/_optimize.py:2989: RuntimeWarning: invalid value encountered in scalar divide
#   w = xb - ((xb - xc) * tmp2 - (xb - xa) * tmp1) / denom
# /home/fcastellano/.conda/envs/memoria/lib/python3.10/site-packages/scipy/optimize/_optimize.py:2488: RuntimeWarning: invalid value encountered in scalar subtract
#   tmp1 = (x - w) * (fx - fv)
# /home/fcastellano/.conda/envs/memoria/lib/python3.10/site-packages/scipy/optimize/_optimize.py:2489: RuntimeWarning: invalid value encountered in scalar subtract
#   tmp2 = (x - v) * (fx - fw)
# /home/fcastellano/.conda/envs/memoria/lib/python3.10/site-packages/scipy/optimize/_optimize.py:2489: RuntimeWarning: invalid value encountered in scalar multiply
#   tmp2 = (x - v) * (fx - fw)

# %%
hist_bc
# Out:
# array([[4.9110657e-01, 4.9110657e-01, 4.9110657e-01, ..., 4.9110657e-01,
#         4.9110657e-01, 4.9110657e-01],
#        [4.9110657e-01, 4.9110657e-01, 4.9110657e-01, ..., 4.9110657e-01,
#         4.9110657e-01, 4.9110657e-01],
#        [4.9110657e-01, 4.9110657e-01, 4.9110657e-01, ..., 4.7611561e-01,
#         4.9110657e-01, 4.9110657e-01],
#        ...,
#        [4.9110657e-01, 4.9110657e-01, 4.9110657e-01, ..., 4.0259436e-01,
#         4.9483058e-01, 4.9110657e-01],
#        [4.9110657e-01, 4.9110657e-01, 4.9110657e-01, ..., 4.9854529e-01,
#         4.9110657e-01, 4.9110657e-01],
#        [9.9999997e-06, 9.9999997e-06, 9.9999997e-06, ..., 9.9999997e-06,
#         9.9999997e-06, 9.9999997e-06]], dtype=float32)
