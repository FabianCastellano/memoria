# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import os 
import sys

sys.path.append('../../boxcox')
sys.path.append('../../comparison')
sys.path.append('../../dCor')
sys.path.append('../../local_maximal_corr')
sys.path.append('../../MCI')

from img_comparison import compare_images

from scipy.spatial import distance
from main_lmc import LocalMaximalCorr
from minepy import MINE

from scipy.stats import pearsonr

from scipy import stats
import matplotlib.pyplot as plt

# import to read png as matrix

import numpy as np

# %%
# read image with nunpy
i = 1
img_path = f'../../boxcox/img/{i}.png'
img = plt.imread(img_path)
plt.grid(False)
plt.imshow(img)
# remove grid

# %%
# add noise
img_noise = img + np.random.normal(0, 0.3, img.shape)
plt.grid(False)
plt.imshow(img_noise)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# reduce size of image to 10x10
# img = img[::10, ::10]
# img_noise = img_noise[::10, ::10]

comp = compare_images(img, img_noise)
method = 'full'

# lmc
lmc = lambda x, y: LocalMaximalCorr(x, y).local_maximal_corr()[0]
lmc_res = lmc(img, img_noise)

lmc_res
